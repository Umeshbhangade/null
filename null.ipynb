# %%
#chatbot

import random
responses = {
                "hello": "Hello! How can I assist you with your college admission?",
                "eligibility":"To check your eligibility, please provide your high school GPA and standardized test scores.",
                "application deadline": "The application deadline for the upcoming year is [oct 2023].",
                "tuition cost": "The tuition cost varies depending on your program. Please visit our college or college website for detailedinformation.",
                "programs": "We offer a variety of programs in [Arts commerce Science]. Which one are you interested in?",
                "contact": "You can contact our admission office at admission@mitacsc.edu.in or call us at 91-8055350000.",
                "college":"mit acsc",
                "college address":"MAEER'S MIT Arts,Commerce & Science College Alandi Road, Pune - 412105 Maharashtra, India",
                "Placement ratio":"We offer 100% placement assistance and most of the student got the placement from this college",
                "goodbye": "Thank you for chatting with us. Goodbye!",
                "default": "I'm sorry, I didn't understand your question. Please ask again or provide more details.",
}
def generate_response(user_input):
    
    user_input = user_input.lower()
    if "eligibility" in user_input:
        response = responses["eligibility"]
    elif "deadline" in user_input:
        response = responses["application deadline"]
    elif "tuition" in user_input:
        response = responses["tuition cost"]
    elif "programs" in user_input:
        response = responses["programs"]
    elif "contact" in user_input:
        response = responses["contact"]
    elif "bye" in user_input:
        response = responses["goodbye"]
    elif "hello" in user_input:
        response = responses["hello"]
    elif "college name" in user_input:
        response = responses["college name"]
    elif "placement ratio" in user_input:
        response = responses["placement ratio"]
    elif "college address" in user_input:
        response = responses["college address"]
    else:
        response = responses["default"]

    return response

    print("College Admission Chatbot: Hello! How can I assist you with your college admission? (Type 'bye' to exit)")
    while True:
        user_input = input("You: ")
    if "bye" in user_input.lower():
        print("College Admission Chatbot: Goodbye!")
    break
    else:
        response = generate_response(user_input)
        print("College Admission Chatbot:", response)
        
        
#t Water jug problem
from collections import deque
def Solution(a, b, target):
m = {}
isSolvable = False
path = []
q = deque()
#Initializing with jugs being empty
q.append((0, 0))
while (len(q) > 0):
# Current state
u = q.popleft()
if ((u[0], u[1]) in m):
continue
if ((u[0] > a or u[1] > b or
u[0] < 0 or u[1] < 0)):
continue
path.append([u[0], u[1]])
m[(u[0], u[1])] = 1
if (u[0] == target or u[1] == target):
isSolvable = True
if (u[0] == target):
if (u[1] != 0):
path.append([u[0], 0])
else:
if (u[0] != 0):
path.append([0, u[1]])
sz = len(path)
for i in range(sz):
print("(", path[i][0], ",",
path[i][1], ")")
break
q.append([u[0], b]) # Fill Jug2
q.append([a, u[1]]) # Fill Jug1
for ap in range(max(a, b) + 1):
c = u[0] + ap
d = u[1] - ap
if (c == a or (d == 0 and d >= 0)):
q.append([c, d])
c = u[0] - ap
d = u[1] + ap
if ((c == 0 and c >= 0) or d == b):
q.append([c, d])
q.append([a, 0])
q.append([0, b])
if (not isSolvable):
print("Solution not possible")
if __name__ == '__main__':
Jug1, Jug2, target = 4, 3, 2
print("Path from initial state "
"to solution state ::")
Solution(Jug1, Jug2, target)



#BFS FOR TREE
class TreeNode:
def __init__(self, value):
self.value = value
self.left = None
self.right = None
def breadth_first_search(root):
if root is None:
return
queue = []
result = []
queue.append(root)
while queue:
node = queue.pop(0)
result.append(node.value)
if node.left:
queue.append(node.left)
if node.right:
queue.append(node.right)
return result
# Create a sample binary tree
root = TreeNode(1)
root.left = TreeNode(0)
root.right = TreeNode(3)
root.left.left = TreeNode(6)
root.left.right = TreeNode(5)
root.right.left = TreeNode(9)
root.right.right = TreeNode(7)
print("Breadth-First Search Result:")
print(breadth_first_search(root))



# DFS IN PYTHON
class TreeNode:
def __init__(self, data):
self.data = data
self.left = None
self.right = None
def dfs_inorder(node):
if node:
dfs_inorder(node.left)
print(node.data, end=' ')
dfs_inorder(node.right)
def dfs_preorder(node):
if node:
print(node.data, end=' ')
dfs_preorder(node.left)
dfs_preorder(node.right)
def dfs_postorder(node):
if node:
dfs_postorder(node.left)
dfs_postorder(node.right)
print(node.data, end=' ')
# Sample tree
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)
print("Inorder (DFS):")
dfs_inorder(root)
print("\nPreorder (DFS):")
dfs_preorder(root)
print("\nPostorder (DFS):")
dfs_postorder(root)



# (Nqueen)
N = 8
board=[[0 for i in range(n)]for i in range(n)]
for row in board:
    print(row)
    
    def check_column(board,row,column):
        for i in range(row,-1,-1):
            if board[i](column)==1:
                return False
        return True
    def check_diagonal(board,row,column):
        for i,j in zip(range(row,-1,-1),range(column,-1,-1)):
            if board[i][j]==1:
                return False
            
            for i,j in zip(range(row,-1,-1),range(column,n)):
                if board[i][j]==1:
                    return False
        return True
    def nqn(board,row):
        if row==n:
            return True
        for i in range(n):
            if check_column(board,row,i)==True and check_diagonal(board,row,i)==True:
                board[row][i]=1
                if nqn(board,row+1):
                    return True
                board[row][i]=0
                return False
            
            nqn(board,0)
            for row in board:
                print(row)
                
        
    
        



#
# Out:
#   Cell In[12], line 49
#     else:
#     ^
# SyntaxError: invalid syntax
